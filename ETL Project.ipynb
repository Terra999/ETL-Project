# %%
import pandas as pd
from sqlalchemy import create_engine

from config import (user, password, host, port, database)

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
adult_file = "Resources/adult.csv"
adult_df = pd.read_csv(adult_file)
adult_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
country_file = "Resources/countries_of_the_world.csv"
country_df = pd.read_csv(country_file, decimal=",")
country_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %% [markdown]
# # Transform adult DataFrame

# %%
# # Create a filtered dataframe from specific columns
adult_cols = ["age", "education", "sex", "hours.per.week", "native.country"] 
adult_transformed = adult_df[adult_cols].copy()
adult_transformed.head()

# # Rename the column headers
adult_transformed = adult_transformed.rename(columns={"hours.per.week": "hours_per_week",
                                                     "native.country": "native_country"})
adult_transformed.head()
# Out:
#    age     education     sex  hours_per_week native_country
# 0   90       HS-grad  Female              40  United-States
# 1   82       HS-grad  Female              18  United-States
# 2   66  Some-college  Female              40  United-States
# 3   54       7th-8th  Female              40  United-States
# 4   41  Some-college  Female              40  United-States

# %%
clean_adult_one = adult_transformed.loc[adult_transformed['native_country'] != "?"]
clean_adult = clean_adult_one.loc[clean_adult_one['native_country'] != "Outlying-US(Guam-USVI-etc)"]
clean_adult.head()
# Out:
#    age     education     sex  hours_per_week native_country
# 0   90       HS-grad  Female              40  United-States
# 1   82       HS-grad  Female              18  United-States
# 2   66  Some-college  Female              40  United-States
# 3   54       7th-8th  Female              40  United-States
# 4   41  Some-college  Female              40  United-States

# %%
clean_adult['native_country'].value_counts()
# Out:
# United-States         29170
# Mexico                  643
# Philippines             198
# Germany                 137
# Canada                  121
# Puerto-Rico             114
# El-Salvador             106
# India                   100
# Cuba                     95
# England                  90
# Jamaica                  81
# South                    80
# China                    75
# Italy                    73
# Dominican-Republic       70
# Vietnam                  67
# Guatemala                64
# Japan                    62
# Poland                   60
# Columbia                 59
# Taiwan                   51
# Haiti                    44
# Iran                     43
# Portugal                 37
# Nicaragua                34
# Peru                     31
# Greece                   29
# France                   29
# Ecuador                  28
# Ireland                  24
# Hong                     20
# Cambodia                 19
# Trinadad&Tobago          19
# Thailand                 18
# Laos                     18
# Yugoslavia               16
# Hungary                  13
# Honduras                 13
# Scotland                 12
# Holand-Netherlands        1
# Name: native_country, dtype: int64

# %%
# clean_adult['native_country'].replace('-',' ', inplace=True)
clean_adult['native_country'].replace(['United-States', 'El-Salvador', 'Puerto-Rico', 'Dominican-Republic', 'Holand-Netherlands', 'Trinadad&Tobago'], ['United States', 'El Salvador', 'Puerto Rico', 'Dominican Republic', 'Netherlands', 'Trinidad & Tobago'], inplace=True)
clean_adult['native_country'].value_counts()
# Out:
# C:\Users\trvaughn\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# United States         29170
# Mexico                  643
# Philippines             198
# Germany                 137
# Canada                  121
# Puerto Rico             114
# El Salvador             106
# India                   100
# Cuba                     95
# England                  90
# Jamaica                  81
# South                    80
# China                    75
# Italy                    73
# Dominican Republic       70
# Vietnam                  67
# Guatemala                64
# Japan                    62
# Poland                   60
# Columbia                 59
# Taiwan                   51
# Haiti                    44
# Iran                     43
# Portugal                 37
# Nicaragua                34
# Peru                     31
# France                   29
# Greece                   29
# Ecuador                  28
# Ireland                  24
# Hong                     20
# Cambodia                 19
# Trinidad & Tobago        19
# Thailand                 18
# Laos                     18
# Yugoslavia               16
# Hungary                  13
# Honduras                 13
# Scotland                 12
# Netherlands               1
# Name: native_country, dtype: int64

# %% [markdown]
# # Transform country DataFrame

# %%
# # Create a filtered dataframe from specific columns
country_cols = ["Country", "Region", "Population", "GDP ($ per capita)", "Phones (per 1000)"] 
country_transformed = country_df[country_cols].copy()

# # Rename the column headers
country_transformed = country_transformed.rename(columns={"Country": "native_country",
                                                     "Region": "region",
                                                         "Population": "population",
                                                         "GDP ($ per capita)": "gdp",
                                                         "Phones (per 1000)": "phones_per_1000"})

# # Clean the data by dropping duplicates and setting the index
# country_transformed.drop_duplicates("", inplace=True)
# country_transformed.set_index("", inplace=True)
country_transformed['native_country'] = country_transformed['native_country'].str.rstrip()

# country_transformed['native_country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua & Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia & Herzegovina', 'Botswana', 'Brazil', 'British Virgin Is.',
#        'Brunei', 'Bulgaria', 'Burkina Faso', 'Burma', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Rep.', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo, Dem. Rep.', 'Congo, Repub. of the',
#        'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia, The',
#        'Gaza Strip', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece',
#        'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala',
#        'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kiribati', 'Korea, North', 'Korea, South', 'Kuwait',
#        'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia',
#        'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macau',
#        'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania',
#        'Mauritius', 'Mayotte', 'Mexico', 'Micronesia, Fed. St.',
#        'Moldova', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco',
#        'Mozambique', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'Netherlands Antilles', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'N. Mariana Islands', 'Norway',
#        'Oman', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal',
#        'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts & Nevis', 'Saint Lucia',
#        'St Pierre & Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome & Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname',
#        'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad & Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks & Caicos Is', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Virgin Islands', 'Wallis and Futuna', 'West Bank',
#        'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# country_transformed['native_country'].replace('-',' ', inplace=True)
country_transformed['gdp'].replace('', '0', inplace=True)
country_transformed['gdp'].value_counts()
# Out:
# 800.0      7
# 700.0      6
# 1900.0     5
# 1800.0     5
# 600.0      4
#           ..
# 8300.0     1
# 36000.0    1
# 2700.0     1
# 16900.0    1
# 17200.0    1
# Name: gdp, Length: 130, dtype: int64

# %%
country_transformed['phones_per_1000'].replace('', '0', inplace=True)
country_transformed['phones_per_1000'].value_counts()
country_transformed.dtypes
# Out:
# native_country      object
# region              object
# population           int64
# gdp                float64
# phones_per_1000    float64
# dtype: object

# %% [markdown]
# # Create database connection

# %%
# Create engine
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
conn = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['country', 'adult']

# %% [markdown]
# # Load DataFrames into database

# %%
 country_transformed.to_sql(name='country', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (native_country)=(Afghanistan ) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-13-aa0e94698f3b> in <module>
# ----> 1 country_transformed.to_sql(name='country', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1131             distilled_params,
#    1132             compiled_sql,
# -> 1133             distilled_params,
#    1134         )
#    1135         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#    1260             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (native_country)=(Afghanistan ) already exists.
#
# [SQL: INSERT INTO country (native_country, region, population, gdp, phones_per_1000) VALUES (%(native_country)s, %(region)s, %(population)s, %(gdp)s, %(phones_per_1000)s)]
# [parameters: ({'native_country': 'Afghanistan ', 'region': 'ASIA (EX. NEAR EAST)         ', 'population': 31056997, 'gdp': 700.0, 'phones_per_1000': 3.2}, {'native_country': 'Albania ', 'region': 'EASTERN EUROPE                     ', 'population': 3581655, 'gdp': 4500.0, 'phones_per_1000': 71.2}, {'native_country': 'Algeria ', 'region': 'NORTHERN AFRICA                    ', 'population': 32930091, 'gdp': 6000.0, 'phones_per_1000': 78.1}, {'native_country': 'American Samoa ', 'region': 'OCEANIA                            ', 'population': 57794, 'gdp': 8000.0, 'phones_per_1000': 259.5}, {'native_country': 'Andorra ', 'region': 'WESTERN EUROPE                     ', 'population': 71201, 'gdp': 19000.0, 'phones_per_1000': 497.2}, {'native_country': 'Angola ', 'region': 'SUB-SAHARAN AFRICA                 ', 'population': 12127071, 'gdp': 1900.0, 'phones_per_1000': 7.8}, {'native_country': 'Anguilla ', 'region': 'LATIN AMER. & CARIB    ', 'population': 13477, 'gdp': 8600.0, 'phones_per_1000': 460.0}, {'native_country': 'Antigua & Barbuda ', 'region': 'LATIN AMER. & CARIB    ', 'population': 69108, 'gdp': 11000.0, 'phones_per_1000': 549.9}  ... displaying 10 of 227 total bound parameter sets ...  {'native_country': 'Zambia ', 'region': 'SUB-SAHARAN AFRICA                 ', 'population': 11502010, 'gdp': 800.0, 'phones_per_1000': 8.2}, {'native_country': 'Zimbabwe ', 'region': 'SUB-SAHARAN AFRICA                 ', 'population': 12236805, 'gdp': 1900.0, 'phones_per_1000': 26.8})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
 clean_adult.to_sql(name='adult', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# ForeignKeyViolation: insert or update on table "adult" violates foreign key constraint "country_fk"
# DETAIL:  Key (native_country)=(United States) is not present in table "country".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-14-923e6845e744> in <module>
# ----> 1 clean_adult.to_sql(name='adult', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1131             distilled_params,
#    1132             compiled_sql,
# -> 1133             distilled_params,
#    1134         )
#    1135         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316         except BaseException as e:
#    1317             self._handle_dbapi_exception(
# -> 1318                 e, statement, parameters, cursor, context
#    1319             )
#    1320
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510             elif should_wrap:
#    1511                 util.raise_(
# -> 1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#    1514             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#    1260             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "adult" violates foreign key constraint "country_fk"
# DETAIL:  Key (native_country)=(United States) is not present in table "country".
#
# [SQL: INSERT INTO adult (age, education, sex, hours_per_week, native_country) VALUES (%(age)s, %(education)s, %(sex)s, %(hours_per_week)s, %(native_country)s)]
# [parameters: ({'age': 90, 'education': 'HS-grad', 'sex': 'Female', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 82, 'education': 'HS-grad', 'sex': 'Female', 'hours_per_week': 18, 'native_country': 'United States'}, {'age': 66, 'education': 'Some-college', 'sex': 'Female', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 54, 'education': '7th-8th', 'sex': 'Female', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 41, 'education': 'Some-college', 'sex': 'Female', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 34, 'education': 'HS-grad', 'sex': 'Female', 'hours_per_week': 45, 'native_country': 'United States'}, {'age': 38, 'education': '10th', 'sex': 'Male', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 74, 'education': 'Doctorate', 'sex': 'Female', 'hours_per_week': 20, 'native_country': 'United States'}  ... displaying 10 of 31964 total bound parameter sets ...  {'age': 58, 'education': 'HS-grad', 'sex': 'Female', 'hours_per_week': 40, 'native_country': 'United States'}, {'age': 22, 'education': 'HS-grad', 'sex': 'Male', 'hours_per_week': 20, 'native_country': 'United States'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
